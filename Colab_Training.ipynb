# %% [markdown]
# # Hindi Handwriting AI - Colab Environment
#
# This notebook allows you to easily verify, train, and evaluate the handwriting models.

# %%
# Cell 1: Install requirements
# !pip install -r requirements_colab.txt

# %%
# Cell 2: Mount Drive (Optional, for persistent storage)
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# Cell 3: Verify Environment and Dataset
# !python main.py setup
# !python main.py info

# %%
# Cell 4: Train Model
# !python main.py train

# %%
# Cell 5: Resume Training (replace EXP_ID with the actual experiment folder name)
# !python main.py resume --exp_id 2026-07-31_001_baseline_lstm

# %%
# Cell 6: Evaluate Best Model
# !python main.py evaluate

# %%
# Cell 7: Generate Previews
# !python main.py preview

# %%
# Cell 8: Download Experiment (creates a zip file to download locally)
# !zip -r my_experiment.zip runs/2026-07-31_001_baseline_lstm
# from google.colab import files
# files.download('my_experiment.zip')

# %%
# Cell 9: Visualize predictions
# import matplotlib.pyplot as plt
# import matplotlib.image as mpimg
# img = mpimg.imread('runs/YOUR_EXP_ID/predictions/final_prediction.svg')
# plt.imshow(img)
# plt.axis('off')
# plt.show()
